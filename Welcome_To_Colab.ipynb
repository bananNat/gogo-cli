# %% [markdown]
# <a href="https://colab.research.google.com/github/bananNat/gogo-cli/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# !unrar x "ML Security.rar"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from ML Security.rar
#
# Creating    ML Security                                               OK
#   OK
# Creating    ML Security/configs                                       OK
#   OK
# Creating    ML Security/data                                          OK
# Creating    ML Security/data/features                                 OK
#   OK
# Creating    ML Security/data/processed                                OK
#   OK
# Creating    ML Security/data/raw                                      OK
#   OK
# Creating    ML Security/docs                                          OK
#   OK
#   OK
# Creating    ML Security/notebooks                                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    ML Security/results                                       OK
# Creating    ML Security/results/figures                               OK
#   OK
# ...
